# %%
data = {
        'venue':"Dolphin Tavern",
        "name":"Josh Test, Josh Test2, Captain Jack",
        "email":"josh@leadcapitalagency.com,admin@leadcapitalagency.com",
        "LinkedIn Profile":"linkedin.com,linkedin.com",
        "Title":"President,President",
        "source":"Outbound Research",
        "campaign" :"reviews",
        "Review Link":"https://search.google.com/local/reviews?placeid=ChIJcwcnPBDGxokRkgvUEr-tXwI",
        "Owner":"Derek Pacque",
        "Rating": "XtraHot",
        "Location Link":"https://www.google.com/maps/place/Dolphin Tavern/@39.930577899999996,-75.168071,14z/data=!4m8!1m2!2m1!1sDolphin Tavern!3m4!1s0x89c6c6103c270773:0x25fadbf12d40b92!8m2!3d39.930577899999996!4d-75.168071",
        "Venue Type" :"Night Club",
        "Review Source": "Review Source",
        "City" :"Philadelphia",
        "State":"Pennsylvania",
        "lat" :"39.9305779",
        "Long" :"-75.168071",
        "Country":"US",
        "Phone":"1 215-278-7950",
        "street":"1539 S Broad St",
        "postal": "19147",
        "venuerating":"4,5"
        }
split_list = []
convert_list = []
data_list = []
b = 0
list_to_dict = []


for i in data.items():
    if ',' in i[1]:
        if "google.com/maps" not in i[1]:       
            split_list.append(i[1].split(','))
        else:
            convert_list.append(i[1])
            split_list.append(convert_list)
            convert_list = []
    else:
        convert_list.append(i[1])
        split_list.append(convert_list)
        convert_list = []

for i in split_list:
    if (len(i))>b:
        b=len(i)


for i in split_list:
    a = b - len(i)
    for j in range(0, a):
        i.append(' ')
    data_list.append(i)

for i in data_list:
    print(i)
# Out:
# ['Dolphin Tavern', ' ', ' ']
# ['Josh Test', ' Josh Test2', ' Captain Jack']
# ['josh@leadcapitalagency.com', 'admin@leadcapitalagency.com', ' ']
# ['linkedin.com', 'linkedin.com', ' ']
# ['President', 'President', ' ']
# ['Outbound Research', ' ', ' ']
# ['reviews', ' ', ' ']
# ['https://search.google.com/local/reviews?placeid=ChIJcwcnPBDGxokRkgvUEr-tXwI', ' ', ' ']
# ['Derek Pacque', ' ', ' ']
# ['XtraHot', ' ', ' ']
# ['https://www.google.com/maps/place/Dolphin Tavern/@39.930577899999996,-75.168071,14z/data=!4m8!1m2!2m1!1sDolphin Tavern!3m4!1s0x89c6c6103c270773:0x25fadbf12d40b92!8m2!3d39.930577899999996!4d-75.168071', ' ', ' ']
# ['Night Club', ' ', ' ']
# ['Review Source', ' ', ' ']
# ['Philadelphia', ' ', ' ']
# ['Pennsylvania', ' ', ' ']
# ['39.9305779', ' ', ' ']
# ['-75.168071', ' ', ' ']
# ['US', ' ', ' ']
# ['1 215-278-7950', ' ', ' ']
# ['1539 S Broad St', ' ', ' ']
# ['19147', ' ', ' ']
# ['4', '5', ' ']

# %%
yet to be conmplete
a = input("Enter the list items : ").split()
for i in a:
    print(data[i])
